# %%
import torch
state_dict = torch.load("/data/workdirs/bevfusion/depth_map6/latest.pth")
print(type(state_dict))

for i in state_dict:
    print(i)
    print(type(state_dict[i]))
    print("aa:",state_dict[i].data.size())
    print("bb:",state_dict[i].requires_grad)
    break
# Out:
# <class 'dict'>
# meta
# <class 'dict'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       6 print(i)
#       7 print(type(state_dict[i]))
# ----> 8 print("aa:",state_dict[i].data.size())
#       9 print("bb:",state_dict[i].requires_grad)
#      10 break
#
# AttributeError: 'dict' object has no attribute 'data'

# %%
print(state_dict.keys())
# Out:
# dict_keys(['meta', 'state_dict', 'optimizer'])

# %%
print(state_dict['meta'])
# Out:
# {'fp16': {'loss_scaler': {'scale': 512.0, 'growth_factor': 2.0, 'backoff_factor': 0.5, 'growth_interval': 2000, '_growth_tracker': 208}}, 'hook_msgs': {'last_ckpt': '/data/workdirs/bevfusion/depth_map6/epoch_5.pth'}, 'epoch': 6, 'iter': 123582, 'mmcv_version': '1.4.0', 'time': 'Sun Dec 24 15:42:10 2023'}

# %%
print(state_dict['state_dict']['encoders.camera.vtransform.depth_map_transform.0.weight'].shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(state_dict['state_dict']['encoders.camera.vtransform.depth_map_transform.0.weight'].shape)
#
# KeyError: 'encoders.camera.vtransform.depth_map_transform.0.weight'

# %%
print(state_dict['state_dict'].keys())
# Out:
# odict_keys(['encoders.camera.backbone.patch_embed.projection.weight', 'encoders.camera.backbone.patch_embed.projection.bias', 'encoders.camera.backbone.patch_embed.norm.weight', 'encoders.camera.backbone.patch_embed.norm.bias', 'encoders.camera.backbone.stages.0.blocks.0.norm1.weight', 'encoders.camera.backbone.stages.0.blocks.0.norm1.bias', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.relative_position_index', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.qkv.weight', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.qkv.bias', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.proj.weight', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.proj.bias', 'encoders.camera.backbone.stages.0.blocks.0.norm2.weight', 'encoders.camera.backbone.stages.0.blocks.0.norm2.bias', 'encoders.camera.backbone.stages.0.blocks.0.ffn.layers.0.0.weight', 'encoders.camera.backbone.stages.
# ...

# %%
print(state_dict['state_dict'].keys())
# Out:
# odict_keys(['encoders.camera.backbone.patch_embed.projection.weight', 'encoders.camera.backbone.patch_embed.projection.bias', 'encoders.camera.backbone.patch_embed.norm.weight', 'encoders.camera.backbone.patch_embed.norm.bias', 'encoders.camera.backbone.stages.0.blocks.0.norm1.weight', 'encoders.camera.backbone.stages.0.blocks.0.norm1.bias', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.relative_position_index', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.qkv.weight', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.qkv.bias', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.proj.weight', 'encoders.camera.backbone.stages.0.blocks.0.attn.w_msa.proj.bias', 'encoders.camera.backbone.stages.0.blocks.0.norm2.weight', 'encoders.camera.backbone.stages.0.blocks.0.norm2.bias', 'encoders.camera.backbone.stages.0.blocks.0.ffn.layers.0.0.weight', 'encoders.camera.backbone.stages.
# ...
